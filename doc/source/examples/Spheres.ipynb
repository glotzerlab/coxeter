# %% [markdown]
# # Computing inspheres, maximal bounded sphere and minimal bounding spheres
#
# Under different conditions, various types of spheres containing or contained within a shape can be useful.
# For example, for spheres contained in a shape we may be interested in the largest sphere contained by a shape, or the largest *concentric* sphere contained within the shape.
# For a polyhedron, we may instead want to find the sphere that touches all the faces, if it exists.

# %%
import fresnel
import numpy as np
import coxeter

# %%
def plot_polyhedron_with_sphere(shape, sphere, inside = True):
    """Image a polyhedron along with a sphere contain it or contained within it."""
    device = fresnel.Device()
    scene = fresnel.Scene(device)

    transparent_material = fresnel.material.Material(
        color=fresnel.color.linear([1, 1, 1]),
        spec_trans=0.95,
        roughness=0.2,
        primitive_color_mix=0.0,
    )
    colored_material = fresnel.material.Material(
        color=fresnel.color.linear([0.9, 0.714, 0.169]),
        roughness=0.8,
    )

    # First make the shape and set up its properties.
    primitive = fresnel.geometry.ConvexPolyhedron(
        scene,
        fresnel.util.convex_polyhedron_from_vertices(shape.vertices),
        N=1,
        outline_width=0.01,
        material=transparent_material if inside else colored_material,
    )
    primitive.color_by_face = 0.0

    # Now draw the sphere and set its centroid.
    draw_sphere = fresnel.geometry.Sphere(
        scene,
        position=sphere.centroid,
        N=1,
        material=colored_material if inside else transparent_material,
    )

    # Make the sphere a little bit smaller than it really is,
    # otherwise you get artifacts near the intersection of the
    # polyhedron and the insphere.
    draw_sphere.radius[:] = [
        sphere.radius * 0.99 if inside else sphere.radius * 1.01
    ]

    scene.camera = fresnel.camera.Orthographic.fit(scene, view="auto")
    tracer = fresnel.tracer.Path(device=device, w=300, h=300)
    return tracer.sample(scene, samples=24, light_samples=40)

# %% [markdown]
# The [Platonic solids](https://en.wikipedia.org/wiki/Platonic_solid) are a canonical set of shapes we can use for our analysis.
# Conveniently, they can easily be generated using coxeter.
# A good example is the dodecahedron.

# %%
dodecahedron = coxeter.families.PlatonicFamily.get_shape("Dodecahedron")

# %% [markdown]
# We will also use a non-regular polyhedron to demonstrate cases where these sphere definitions differ.

# %%
vertices = [[0,1,-1],
            [0,1,1],
            [0,-1,-1],
            [0,-1,1],
            [np.sqrt(2),0,0],
            [0.2,1,-1],
            [0.2,1,1],
            [0.2,-1,-1],
            [0.2,-1,1]
            ]
random_shape = coxeter.shapes.ConvexPolyhedron(vertices)

# %% [markdown]
# We can query different types of spheres from this shape now:

# %% [markdown]
# An insphere is a sphere tangent to every face of a polyhedron.

# %%
print(dodecahedron.insphere)
# Out:
# coxeter.shapes.Sphere(radius=0.564800078028144, center=[3.270247592344183e-17, -8.870611801629848e-17, 2.4178048801514813e-16])

# %% [markdown]
# Let's visualize it:

# %%
plot_polyhedron_with_sphere(dodecahedron, dodecahedron.insphere, True)

# %% [markdown]
# A general polyhedron may not have an insphere, but we can still compute the largest *concentric* sphere contained within the shape.

# %%
print(random_shape.maximal_centered_bounded_sphere)
plot_polyhedron_with_sphere(random_shape, random_shape.maximal_centered_bounded_sphere, True)
# Out:
# coxeter.shapes.Sphere(radius=0.37008948128413927, center=[0.37008948128413927, 0.0, 0.0])

# %% [markdown]
# If we instead want to look at spheres _containing_ a shape, we can get those as well.
#
# Here's the smallest *concentric* sphere containing the shape.

# %%
print(random_shape.minimal_centered_bounding_sphere)
plot_polyhedron_with_sphere(random_shape, random_shape.minimal_centered_bounding_sphere, False)
# Out:
# coxeter.shapes.Sphere(radius=1.461836592836957, center=[0.37008948128413927, 0.0, 0.0])

# %% [markdown]
# We can also compute the smallest bounding sphere without requiring it to be concentric with the shape.

# %%
print(random_shape.minimal_bounding_sphere)
plot_polyhedron_with_sphere(random_shape, random_shape.minimal_bounding_sphere, False)
# Out:
# coxeter.shapes.Sphere(radius=1.4177446878757824, center=[0.10000000000000003, 1.1102230246251565e-16, 1.1102230246251565e-16])
